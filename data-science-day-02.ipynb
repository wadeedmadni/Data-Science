# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# # **Indexing**

# %%
a = "We are doing a 60 day challange"
a
# Out:
# 'We are doing a 60 day challange'

# %%
a[1]
# Out:
# 'e'

# %%
a[0]
# Out:
# 'W'

# %%
len(a)
# Out:
# 31

# %%
a[0:12]
# Out:
# 'We are doing'

# %%
a[:12]
# Out:
# 'We are doing'

# %%
a[7:31]
# Out:
# 'doing a 60 day challange'

# %%
a[-3:]
# Out:
# 'nge'

# %% [markdown]
# # **String Methods**

# %%
food = "Burger"
food_1 = "pizza"
food
# Out:
# 'Burger'

# %%
len(food)
# Out:
# 6

# %%
food_1.capitalize()
# Out:
# 'Pizza'

# %%
food.upper()
# Out:
# 'BURGER'

# %%
food.lower()
# Out:
# 'burger'

# %%
food.replace("B", "Sh")
# Out:
# 'Shurger'

# %%
# finding the number of times a specific letter is appearing in a string
name = "Wadeed Madni"
name
# Out:
# 'Wadeed Madni'

# %%
name.count("d")
# Out:
# 3

# %%
name.find("d")
# Out:
# 2

# %%
name.split(" ")
# Out:
# ['Wadeed', 'Madni']

# %% [markdown]
# # **Data Structures**

# %% [markdown]
# 1. Tuple
# 2. List
# 3. Dictionaries
# 4. Set

# %% [markdown]
# **1. Tuple**
# * Ordered collection of elements
# * enclosed in () round braces / paranthesis
# * different kind of elements can be stored
# * once elements are stores, you can not change them also called unmutable

# %%
tup_1 = (1, "data", True, 4.7)
tup_1
# Out:
# (1, 'data', True, 4.7)

# %%
type(tup_1)
# Out:
# tuple

# %% [markdown]
# **Indexing in Tuple**

# %%
tup_1[2]
# Out:
# True

# %%
tup_1[1]
# Out:
# 'data'

# %%
tup_1[2:4]
# Out:
# (True, 4.7)

# %%
len(tup_1)
# Out:
# 4

# %%
tup_2 = (3, "science", "challange", 1.8)
tup_1 + tup_2
# Out:
# (1, 'data', True, 4.7, 3, 'science', 'challange', 1.8)

# %%
tup_1*2 + tup_2
# Out:
# (1, 'data', True, 4.7, 1, 'data', True, 4.7, 3, 'science', 'challange', 1.8)

# %% [markdown]
# **2. List**
# * Ordered collection of elements
# * Enclosed in [] sqaure brackets
# * Values can be changed, mutable

# %%
list_1 = [1, "data", True, 4.7]
list_1
# Out:
# [1, 'data', True, 4.7]

# %%
type(list_1)
# Out:
# list

# %%
len(list_1)
# Out:
# 4

# %%
list_2 = [3, 8.5, "Wadeed", False, "Madni", 3425]
list_2
# Out:
# [3, 8.5, 'Wadeed', False, 'Madni', 3425]

# %%
list_1 +list_2
# Out:
# [1, 'data', True, 4.7, 3, 8.5, 'Wadeed', False, 'Madni', 3425]

# %%
list_1.reverse()
list_1
# Out:
# [4.7, True, 'data', 1]

# %%
list_1.append(96)
list_1
# Out:
# [4.7, True, 'data', 1, 96]

# %%
list_1.pop(2)
list_1
# Out:
# [4.7, True, 1, 96]

# %%
list_1.append("data")

# %%
list_1
# Out:
# [4.7, True, 1, 96, 'data']

# %%
list_3 = [23, 24, 43, 743, 13, 2463, 1426, 2435, 1, 64, 999]
list_3
# Out:
# [23, 24, 43, 743, 13, 2463, 1426, 2435, 1, 64, 999]

# %%
list_3.sort()
list_3
# Out:
# [1, 13, 23, 24, 43, 64, 743, 999, 1426, 2435, 2463]

# %%
# use case list: a resturant owner sells 10 items on normal days but adds some special items on the basis of events and he wants to add
# that list of items to his new menu

daily_menu = ["Pizza", "Burger", "Sandwich", "Coffee", "Tea"]
independence_day_specials = ["Patriot Chiken Wings", "Fighter Lobster", "Breezy Pina Coloda", "Loyal Pan Cakes"]

# %%
daily_menu
# Out:
# ['Pizza', 'Burger', 'Sandwich', 'Coffee', 'Tea']

# %%
independence_day_specials
# Out:
# ['Patriot Chiken Wings',
#  'Fighter Lobster',
#  'Breezy Pina Coloda',
#  'Loyal Pan Cakes']

# %%
independence_day_menu = daily_menu + independence_day_specials
independence_day_menu
# Out:
# ['Pizza',
#  'Burger',
#  'Sandwich',
#  'Coffee',
#  'Tea',
#  'Patriot Chiken Wings',
#  'Fighter Lobster',
#  'Breezy Pina Coloda',
#  'Loyal Pan Cakes']

# %%
# we can use input with if else conditons to show menue if its independece day orlese the daily menu
date = input("what date is it today in the month of july? ")
def show_menu(date):
    if date == "4":
        
        print(independence_day_menu)
    else:
        print(daily_menu)
        
show_menu(date)
# Out:
# what date is it today in the month of july?  4
# ['Pizza', 'Burger', 'Sandwich', 'Coffee', 'Tea', 'Patriot Chiken Wings', 'Fighter Lobster', 'Breezy Pina Coloda', 'Loyal Pan Cakes']

# %% [markdown]
# **3. Dictionaries**
# * Unordered collection of elements
# * key and value
# * curly brackets {}
# * can be changed, mutable

# %%
# Menu items and it's prices
menu = {"Pizza":15,"Burger":10,"reezy Pina Coloda":7,"Tea":4}
menu
# Out:
# {'Pizza': 15, 'Burger': 10, 'reezy Pina Coloda': 7, 'Tea': 4}

# %%
menu.keys()
# Out:
# dict_keys(['Pizza', 'Burger', 'reezy Pina Coloda', 'Tea'])

# %%
menu["Fighter Lobster"] = 21
menu
# Out:
# {'Pizza': 15,
#  'Burger': 10,
#  'reezy Pina Coloda': 7,
#  'Tea': 4,
#  'Fighter Lobster': 21}

# %%
# update values
menu["Tea"] = 6
menu
# Out:
# {'Pizza': 15,
#  'Burger': 10,
#  'reezy Pina Coloda': 7,
#  'Tea': 6,
#  'Fighter Lobster': 21}

# %%
#  concatenate
menu1 = {"Rice":9, "Sandwiches":7}
menu1
# Out:
# {'Rice': 9, 'Sandwiches': 7}

# %%
menu.update(menu1)
menu
# Out:
# {'Pizza': 15,
#  'Burger': 10,
#  'reezy Pina Coloda': 7,
#  'Tea': 6,
#  'Fighter Lobster': 21,
#  'Rice': 9,
#  'Sandwiches': 7}

# %% [markdown]
# **4. Sets**
# * unordered and unindexed
# * curly braces are used {}
# * no duplicates allowed

# %%
s1 = {1, 42, 6.3, "Data Science", "Wadeed", True}
s1
# Out:
# {1, 42, 6.3, 'Data Science', 'Wadeed'}

# %%
s1.add("Wadeed")
s1
# Out:
# {1, 42, 6.3, 'Data Science', 'Wadeed'}

# %%
s1.remove(6.3)
s1
# Out:
# {1, 42, 'Data Science', 'Wadeed'}

# %%
s1.
