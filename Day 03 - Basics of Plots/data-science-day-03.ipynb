# %% [markdown]
# # **Line and Bar Plots**
# 1. Seaborn
# 2. numpy
# 3. scipy
# 4. pandas
# 5. matplotlib

# %% [markdown]
# # 1. Line Graph

# %%
# import libraries
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
# load IRIS dataset

df = sns.load_dataset("iris")
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
# adding styles
# always add style before defining the x and y axis or else it won't work
sns.set_style(style=None, rc = None)
sns.set_style("dark")


sns.lineplot(x= "sepal_length", y = "sepal_width", data = df)

# adding title for the graph
plt.title("iris plot graph")

# adding x and y axis limits
# plt.xlim(2)
#plt.ylim(1)

# change figure size
plt.figure(figsize =(8,10))

plt.show()

# %% [markdown]
# # 1. Bar Plot

# %%
sns.barplot(x = "species", y = "petal_length", data = df)
plt.show()

# %% [markdown]
# **Grouping**

# %%
titanic = sns.load_dataset("titanic")
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
import numpy
sns.barplot(x = "class", y = "fare", hue = "sex", data = titanic, color = "orange", errorbar = None, palette = 'pastel', estimator = 'mean', saturation = 1)
plt.show()

# %%
sns.barplot(x = "class", y = "fare", hue = "sex", data = titanic,
            linewidth = 3, errcolor = "0.5",
            color = "orange", errorbar = None, palette = 'pastel', 
            estimator = 'mean', saturation = 1)
# Out:
# <Axes: xlabel='class', ylabel='fare'>

# %% [markdown]
# # **2. Bar Plot**

# %%
import seaborn
seaborn.set(style = 'whitegrid')

seaborn.boxplot(x = "class", y = "fare", data = titanic)
# Out:
# <Axes: xlabel='class', ylabel='fare'>

# %%
import seaborn
seaborn.set(style = 'whitegrid')

tip = seaborn.load_dataset('tips')
tip.head(5)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
seaborn.boxplot(x = "day", y = "tip", data = tip, saturation =1)
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
tip.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
sns.boxplot(x = tip['total_bill'])
# Out:
# <Axes: xlabel='total_bill'>

# %%
sns.boxplot(x = "tip", y = "day", hue = "sex", data = tip, dodge = True)
# Out:
# <Axes: xlabel='tip', ylabel='day'>

# %%
sns.boxplot(x = "day", y = "tip", hue = "sex",showmeans = True,
           meanprops = {'marker':"+",
                       'markersize': 8,
                       'markeredgecolor': "white"},
             data = tip
           )
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %% [markdown]
# # **3. Line Plot with Multifacets**
