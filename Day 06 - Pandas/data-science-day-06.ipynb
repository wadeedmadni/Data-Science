# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/police/police.csv

# %%
df = pd.read_csv("/kaggle/input/police/police.csv")
df.head(10)
# Out:
#     stop_date stop_time  county_name driver_gender  driver_age_raw  \
# 0  2005-01-02     01:55          NaN             M          1985.0
# 1  2005-01-18     08:15          NaN             M          1965.0
# 2  2005-01-23     23:15          NaN             M          1972.0
# 3  2005-02-20     17:15          NaN             M          1986.0
# 4  2005-03-14     10:00          NaN             F          1984.0
# 5  2005-03-23     09:45          NaN             M          1982.0
# 6  2005-04-01     17:30          NaN             M          1969.0
# 7  2005-06-06     13:20          NaN             F          1986.0
# 8  2005-07-13     10:15          NaN             M          1970.0
# 9  2005-07-13     15:45          NaN             M          1970.0
#
#    driver_age driver_race                   violation_raw  violation  \
# 0        20.0       White                        Speeding   Speeding
# 1        40.0       White                        Speeding   Speeding
# ...

# %%
list(df.columns)
# Out:
# ['stop_date',
#  'stop_time',
#  'county_name',
#  'driver_gender',
#  'driver_age_raw',
#  'driver_age',
#  'driver_race',
#  'violation_raw',
#  'violation',
#  'search_conducted',
#  'search_type',
#  'stop_outcome',
#  'is_arrested',
#  'stop_duration',
#  'drugs_related_stop']

# %%
df
# Out:
#         stop_date stop_time  county_name driver_gender  driver_age_raw  \
# 0      2005-01-02     01:55          NaN             M          1985.0
# 1      2005-01-18     08:15          NaN             M          1965.0
# 2      2005-01-23     23:15          NaN             M          1972.0
# 3      2005-02-20     17:15          NaN             M          1986.0
# 4      2005-03-14     10:00          NaN             F          1984.0
# ...           ...       ...          ...           ...             ...
# 91736  2015-12-31     20:27          NaN             M          1986.0
# 91737  2015-12-31     20:35          NaN             F          1982.0
# 91738  2015-12-31     20:45          NaN             M          1992.0
# 91739  2015-12-31     21:42          NaN             M          1993.0
# 91740  2015-12-31     22:46          NaN             M          1959.0
#
#        driver_age driver_race                   violation_raw  \
# ...

# %%
df = df.drop('county_name', axis = 1)
df
# Out:
#         stop_date stop_time driver_gender  driver_age_raw  driver_age  \
# 0      2005-01-02     01:55             M          1985.0        20.0
# 1      2005-01-18     08:15             M          1965.0        40.0
# 2      2005-01-23     23:15             M          1972.0        33.0
# 3      2005-02-20     17:15             M          1986.0        19.0
# 4      2005-03-14     10:00             F          1984.0        21.0
# ...           ...       ...           ...             ...         ...
# 91736  2015-12-31     20:27             M          1986.0        29.0
# 91737  2015-12-31     20:35             F          1982.0        33.0
# 91738  2015-12-31     20:45             M          1992.0        23.0
# 91739  2015-12-31     21:42             M          1993.0        22.0
# 91740  2015-12-31     22:46             M          1959.0        56.0
#
#       driver_race                   violation_raw         violation  \
# ...

# %%
df
# Out:
#         stop_date stop_time driver_gender  driver_age_raw  driver_age  \
# 0      2005-01-02     01:55             M          1985.0        20.0
# 1      2005-01-18     08:15             M          1965.0        40.0
# 2      2005-01-23     23:15             M          1972.0        33.0
# 3      2005-02-20     17:15             M          1986.0        19.0
# 4      2005-03-14     10:00             F          1984.0        21.0
# ...           ...       ...           ...             ...         ...
# 91736  2015-12-31     20:27             M          1986.0        29.0
# 91737  2015-12-31     20:35             F          1982.0        33.0
# 91738  2015-12-31     20:45             M          1992.0        23.0
# 91739  2015-12-31     21:42             M          1993.0        22.0
# 91740  2015-12-31     22:46             M          1959.0        56.0
#
#       driver_race                   violation_raw         violation  \
# ...

# %%
df_to_array = df[['driver_gender', 'driver_age', 'violation_raw', 'drugs_related_stop', 'is_arrested', 'stop_date', 'stop_time']].copy()
df_to_array
# Out:
#       driver_gender  driver_age                   violation_raw  \
# 0                 M        20.0                        Speeding
# 1                 M        40.0                        Speeding
# 2                 M        33.0                        Speeding
# 3                 M        19.0                Call for Service
# 4                 F        21.0                        Speeding
# ...             ...         ...                             ...
# 91736             M        29.0                        Speeding
# 91737             F        33.0  Equipment/Inspection Violation
# 91738             M        23.0         Other Traffic Violation
# 91739             M        22.0                        Speeding
# 91740             M        56.0                        Speeding
#
#        drugs_related_stop is_arrested   stop_date stop_time
# 0                   False       False  2005-01-02     01:55
# 1                   False       False  2005-01-18     08:15
# ...

# %%
df_to_array.loc["20050101":"20080430", ['driver_gender', 'driver_age', 'stop_date']]
# Out:
#       driver_gender  driver_age   stop_date
# 20051             M        29.0  2007-09-10
# 20052             F        27.0  2007-09-10
# 20053             M        24.0  2007-09-10
# 20054           NaN         NaN  2007-09-10
# 20055             M        21.0  2007-09-10
# 20056             M        29.0  2007-09-10
# 20057             M        28.0  2007-09-10
# 20058             M        39.0  2007-09-10
# 20059             M        25.0  2007-09-10
# 20060             M        23.0  2007-09-10
# 20061             M        40.0  2007-09-10
# 20062             F        21.0  2007-09-10
# 20063             M        20.0  2007-09-10
# 20064             M        20.0  2007-09-10
# 20065             M        19.0  2007-09-10
# 20066             F        18.0  2007-09-10
# 20067             F        24.0  2007-09-10
# 20068             M        21.0  2007-09-10
# 20069             M        52.0  2007-09-10
# 20070             F        22.0  2007-09-10
# ...

# %%
df_to_array[0:1000]
# Out:
#     driver_gender  driver_age            violation_raw  drugs_related_stop  \
# 0               M        20.0                 Speeding               False
# 1               M        40.0                 Speeding               False
# 2               M        33.0                 Speeding               False
# 3               M        19.0         Call for Service               False
# 4               F        21.0                 Speeding               False
# ..            ...         ...                      ...                 ...
# 995             M        53.0                 Speeding               False
# 996             M        20.0  Other Traffic Violation               False
# 997             M        46.0  Other Traffic Violation               False
# 998             M        46.0  Other Traffic Violation               False
# 999             M        17.0                 Speeding               False
#
#     is_arrested   stop_date stop_time
# ...

# %%
df_to_array.loc[:, ['driver_gender', 'is_arrested', 'violation_raw']]
# Out:
#       driver_gender is_arrested                   violation_raw
# 0                 M       False                        Speeding
# 1                 M       False                        Speeding
# 2                 M       False                        Speeding
# 3                 M        True                Call for Service
# 4                 F       False                        Speeding
# ...             ...         ...                             ...
# 91736             M       False                        Speeding
# 91737             F       False  Equipment/Inspection Violation
# 91738             M       False         Other Traffic Violation
# 91739             M       False                        Speeding
# 91740             M       False                        Speeding
#
# [91741 rows x 3 columns]

# %%
df_to_array[df_to_array["driver_age"] >= 28]
# Out:
#       driver_gender  driver_age                   violation_raw  \
# 1                 M        40.0                        Speeding
# 2                 M        33.0                        Speeding
# 6                 M        36.0                        Speeding
# 8                 M        35.0                        Speeding
# 9                 M        35.0                        Speeding
# ...             ...         ...                             ...
# 91732             F        46.0                        Speeding
# 91733             F        41.0          Registration Violation
# 91736             M        29.0                        Speeding
# 91737             F        33.0  Equipment/Inspection Violation
# 91740             M        56.0                        Speeding
#
#        drugs_related_stop is_arrested   stop_date stop_time
# 1                   False       False  2005-01-18     08:15
# 2                   False       False  2005-01-23     23:15
# ...

# %%
df_new = df_to_array[:9].copy()
df_new["new_column"] = ["one", "two", "three", "four", "five", "six", "seven", "eight","nine"]
df_new
# Out:
#   driver_gender  driver_age                   violation_raw  \
# 0             M        20.0                        Speeding
# 1             M        40.0                        Speeding
# 2             M        33.0                        Speeding
# 3             M        19.0                Call for Service
# 4             F        21.0                        Speeding
# 5             M        23.0  Equipment/Inspection Violation
# 6             M        36.0                        Speeding
# 7             F        19.0                        Speeding
# 8             M        35.0                        Speeding
#
#    drugs_related_stop is_arrested   stop_date stop_time new_column
# 0               False       False  2005-01-02     01:55        one
# 1               False       False  2005-01-18     08:15        two
# 2               False       False  2005-01-23     23:15      three
# 3               False        True  2005-02-20     17:15       four
# ...

# %%
df_to_array[df_to_array["violation_raw"] == "Speeding"]
# Out:
#       driver_gender  driver_age violation_raw  drugs_related_stop is_arrested  \
# 0                 M        20.0      Speeding               False       False
# 1                 M        40.0      Speeding               False       False
# 2                 M        33.0      Speeding               False       False
# 4                 F        21.0      Speeding               False       False
# 6                 M        36.0      Speeding               False       False
# ...             ...         ...           ...                 ...         ...
# 91734             M        22.0      Speeding               False       False
# 91735             M        23.0      Speeding               False       False
# 91736             M        29.0      Speeding               False       False
# 91739             M        22.0      Speeding               False       False
# 91740             M        56.0      Speeding               False       False
#
#         stop_date stop_time
# ...
